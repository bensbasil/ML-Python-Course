# %%
import logging
##create a logger for module1
logger1=logging.getLogger("module1")
logger1.setLevel(logging.DEBUG)

logger2=logging.getLogger("module2")
logger2.setLevel(logging.WARNING)

##Configure logging settings 
logging.basicConfig(
    level=logging.DEBUG,
    format='%(asctime)s-%(name)s-%(levelname)s-%(message)s',
    datefmt='%Y-%m-%d %H:%M:%S'
)

# %%
#LOGGING WITH DIFFERENT MESSAGES
logger1.debug("This is debug message for module1")
logger2.warning("This is a warning message for module2")
logger2.error("This is an error message")
# Out:
# 2026-01-01 04:52:53-module1-DEBUG-This is debug message for module1
# 2026-01-01 04:52:53-module2-WARNING-This is a warning message for module2
# 2026-01-01 04:52:53-module2-ERROR-This is an error message
