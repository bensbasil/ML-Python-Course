# %%
with open('example.txt','r') as file:
    content=file.read()
    print(content)
# Out:
# hi my name is bens
# im from trivandrum
# how are you

# %%
with open('example.txt','w') as file:
    file.write('Hello world!\n')
    file.write('This is a new line')

# %%
with open('example.txt','a') as file:
    file.write('append operation takes place!\n')

# %%
lines=['first line \n', 'second line\n','Third line\n']
with open('example.txt','a') as file:
    file.writelines(lines)

# %%
##binary files
data=b'\x00\x01\x02\x03\x04'
with open('example.bin','wb') as file:
        file.write(data)

# %%
with open('example.bin','rb') as file:
        content=file.read()
        print(content)
# Out:
# b'\x00\x01\x02\x03\x04'

# %%
with open('example.txt','r') as source_file:
    content=source_file.read()

with open('destination','w') as destination_file:
    destination_file.write(content)

# %%
def count_text_file(file_path):
    with open(file_path,'r') as file:
        lines=file.readlines()
        line_count=len(lines)
        word_count=sum(len(line.split()) for line in lines)
        char_count=sum(len(line) for line in lines)
    return line_count, word_count, char_count

file_path='example.txt'
lines, words, characters=count_text_file(file_path)
print(f'Lines: {lines}, Words: {words}, Characters: {characters}')
# Out:
# Lines: 2, Words: 4, Characters: 22

# %%
with open ('example.txt','w+') as file:
    file.write("Hello world\n")
    file.write("this is a new line\n")

    file.seek(0)
    content=file.read()
    print(content)
# Out:
# Hello world
# this is a new line

# %%
##create a new dictionary
import os
new_directory="package"
os.mkdir(new_directory)
print(f"Directory '{new_directory}' create")
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[13], line 4
#       2 import os
#       3 new_directory="package"
# ----> 4 os.mkdir(new_directory)
#       5 print(f"Directory '{new_directory}' create")
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'package'

# %%
items=os.listdir('.')
print(items)
# Out:
# ['benms', 'destination', 'example.bin', 'example.txt', 'files.ipynb', 'package', 'sample_bistto.txt']

# %%
dir_name="folder"
file_name="file.txt"
full_path=os.path.join(dir_name,file_name)
print(full_path)
# Out:
# folder\file.txt

# %%
path='example1.txt'
if os.path.exists(path):
    print(f"The path '{path}' exists")
else:
    print(f"The path '{path}' does not exists")
# Out:
# The path 'example1.txt' does not exists

# %%
path='file_operations'
if os.path.isfile(path):
    print(f"The path '{path}' exists")
elif os.path.isdir(path):
    print(f"The path '{path}' is a directory")
else:
    print(f"The path '{path}' is neither a file nor a directory")
# Out:
# The path 'file_operations' is neither a file nor a directory

# %%
##getting the absolute path
relative_path='example.txt'
absolute_path=os.path.abspath(relative_path)
print(absolute_path)
# Out:
# d:\DATA_SCIENCE\python\modules\file_operations\example.txt

# %%
##Exception try, exception block    
try:
    a=b
except:
    print("The variable has not been assigned")
# Out:
# The variable has not been assigned

# %%
try:
    a=b
except NameError as ex:
    print(ex)
# Out:
# name 'b' is not defined

# %%
try:
   result=1/0
except ZeroDivisionError as ex:
   print(ex)
   print("Please Enter the denominator greater than 0")
# Out:
# division by zero
# Please Enter the denominator greater than 0

# %%
try:
   result=1/0
   a=b
except ZeroDivisionError as ex:
   print(ex)
   print("Please Enter the denominator greater than 0")
except Exception as ex1:
   print(ex1)
   print('Main exception got caught here')
# Out:
# division by zero
# Please Enter the denominator greater than 0

# %%
try:
    num=int(input("Enter a number"))
    result=10/num
except ValueError:
    print("this is not a valid number")

except ZeroDivisionError:
    print("enter the denominator greater than 0")
except Exception as ex:
    print(ex)

# %%
try:
    num=int(input("Enter the number:"))
    result=10/num
except ValueError:
    print("thats not a valid number!")
except ZeroDivisionError:
    print("you cant divide by zero")
except Exception as ex:
    print(ex)
else:
    print(f"the result is {result}")
finally:
    print("Exception complete")
# Out:
# the result is 5.0
# Exception complete

# %%
try:
    file=open('example.txt','r')
    content=file.read()
    a=b
    print(content)

except FileNotFoundError:
    print("the file does not exists")
except Exception as ex:
    print(ex)
finally:
    if 'file' in locals() or not file.closed():
        file.close()
        print('file close')
# Out:
# name 'b' is not defined
# file close

# %%
class Car:
    pass

audi=Car()
bmw=Car()

print(type(audi))
# Out:
# <class '__main__.Car'>

# %%
print(audi)
print(bmw)
# Out:
# <__main__.Car object at 0x0000022F53C0D2B0>
# <__main__.Car object at 0x0000022F53A17ED0>

# %%
audi.windows=4
print(audi.windows)
# Out:
# 4

# %%
tata=Car()
tata.doors=5
print(tata.windows)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 3
#       1 tata=Car()
#       2 tata.doors=5
# ----> 3 print(tata.windows)
#
# AttributeError: 'Car' object has no attribute 'windows'

# %%
dir(tata)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'doors']

# %%
class Dog:
     def __init__(self,name,age):
        self.name=name
        self.age=age

dog1=Dog("Buddy",3)
print(dog1)
print(dog1.name)
print(dog1.age)
# Out:
# <__main__.Dog object at 0x000001BB67B4E120>
# Buddy
# 3

# %%
dog2=Dog("Lucy",4)
print(dog2.name)
print(dog2.age)
# Out:
# Lucy
# 4

# %%
class Dog:
    def __init__(self,name,age):
        self.name=name
        self.age=age

    def bark(self):
        print(f"{self.name} says woof")

dog1=Dog("Buddy",3)
dog1.bark()
dog2=Dog("Lucy",4)
dog2.bark()
# Out:
# Buddy says woof
# Lucy says woof

# %%
class BankAccount:
    def __init__(self,owner,balance=0):
        self.owner=owner
        self.balance=balance

    def deposit(self,amount):
        self.balance+=amount
        print(f"{amount} is deposited. New balance is {self.balance}")

    def withdraw(self,amount):
        if amount>self.balance:
            print("Insufficient funds!")
        else:
            self.balance-=amount
            print(f"{amount} is withdrawn, New Balance is {self.balance}")

    def get_balance(self):
        return self.balance
    

account=BankAccount("Bens",5000)
print(account.balance)
# Out:
# 5000

# %%
account.deposit(100)
# Out:
# 100 is deposited. New balance is 5100

# %%
account.withdraw(1000)
# Out:
# 1000 is withdrawn, New Balance is 4100

# %%
print(account.get_balance())
# Out:
# 4100

# %%
class Car:
    def __init__(self,windows,doors,enginetype):
       self.windows=windows
       self.doors=doors
       self.enginetype=enginetype
    
    def drive(self):
        print(f"The person will drive the {self.enginetype} car")

# %%
car1=Car(4,5,"petrol")
print(car1.drive())
# Out:
# The person will drive the petrol car
# None

# %%
class Tesla(Car):
    def __init__(self,windows,doors,enginetype,is_selfdriving):
        super().__init__(windows,doors,enginetype)
        self.is_selfdriving=is_selfdriving

    def selfdriving(self):
        print(f"Tesla supports self driving : {self.is_selfdriving} car")

# %%
tesla1=Tesla(4,5,"electric",True)
tesla1.selfdriving()
# Out:
# Tesla supports self driving : True car

# %%
tesla1.drive()
# Out:
# The person will drive the electric car

# %%
#Multiple Inheritance
##When a class inherits more than one

class Animal:
    def __init__(self,name):
        self.name=name

    def speak(self):
        print("Subclass must implement this method")

## Base class 2
class Pet:
    def __init__(self,owner):
        self.owner= owner

class Dog(Animal,Pet):
    def __init__(self,name,owner):
        Animal.__init__(self,name)
        Pet.__init__(self,owner)

    def speak(self):
        return f"{self.name} say woof"
    
dog=Dog("Buddy","Bens")
print(dog.speak())
print(f"Owner : {dog.owner}")
# Out:
# Buddy say woof
# Owner : Bens

# %%
### Methods Overriding 
class Animal:
    def speak(self):
        return "Sound of the animal"
    
##Derived class 1
class Dog:
    def speak(self):
        return "woof!"
    
##Derived class 2

class Cat:
    def speak(self):
        return "meow!"
    
##fUNCTION THAT IS DERIVED  
def animal_speak(animal):
    print(animal.speak())
    
dog=Dog()
cat=Cat()
print(dog.speak())
print(cat.speak())
animal_speak(dog)
# Out:
# woof!
# meow!
# woof!

# %%
#Polymorphism with functions and methods
class Shape:
    def area(self):
        return "The area of the figure"
    
##Derived class 1
class Rectangle(Shape):
    def __init__(self,width,height):
        self.width=width
        self.height=height

    def area(self):
        return self.width * self.height
    
##Derived class 2

class Circle(Shape):
    def __init__(self,radius):
        self.radius=radius
    def area(self):
        return 3.14*self.radius*self.radius
    
##Polymorphism

def print_area(shape):
    print(f"the area is {shape.area()}")

rectangle=Rectangle(4,5)
circle=Circle(3)
print_area(rectangle)
print_area(circle)
# Out:
# the area is 20
# the area is 28.259999999999998

# %%
##Polymorphism through Abstract Class

from abc import ABC,abstractmethod

##Define an abstract class
class Vehicle(ABC):
    @abstractmethod 
    def start_engine(self):
        pass

## Derived class 1
class Car(Vehicle):
    def start_engine(self):
        return "Car engine started"
    
## Derived class 2
class Motorcycle(Vehicle):
    def start_engine(self):
        return "Motorcycle engine started"
    
def start_vehicle(vehicle):
    print(vehicle.start_engine())

## create objects of car and motorcycle

car=Car()
motorcycle=Motorcycle()

start_vehicle(car)
# Out:
# Car engine started

# %%
##Encapsulation with getter and setter methods
##public,private,protected variables or access modifiers

class Person:
    def __init__(self,name,age):
        self.name=name
        self.age=age

def get_name(person):
    return person.name

person=Person('Bens',32)
get_name(person)
# Out:
# 'Bens'

# %%
class Person:
    def __init__(self,name,age,gender):
        self._name=name #Protected
        self._age=age   #Protected
        self.gender=gender

class Employee(Person):
    def __init__(self,name,age,gender):
        super().__init__(name,age,gender)


employee=Employee("Bens",32,"male")
print(employee._name)
# Out:
# Bens

# %%
class Person:
    def __init__(self,name,age):
        self.__name=name
        self.__age=age

    def get_name(self):
        return self.__name
    def set_name(self,name):
        self.__name=name
    def get_age(self):
        return self.__age
    def set_age(self,age):
        if age>0:
            self.__age=age
        else:
            print("Age cant be negative")
    
person=Person("Bens",33)
print(person.get_name())
print(person.get_age())
person.set_name("alwin")
person.set_age(56)     
print(person.get_name())
print(person.get_age())
# Out:
# Bens
# 33
# alwin
# 56

# %%
from abc import ABC,abstractmethod

##Abstract base class
class Vehicle:
    def drive(self):
        print("The vechicle is used for driving")

    @abstractmethod
    def start_engine(self):
        pass
class Car(Vehicle):
    def start_engine(self):
        print("Car engine started")

def operate_vehicle(vehicle):
    vehicle.start_engine()
    vehicle.drive()

car=Car()
operate_vehicle(car)
# Out:
# Car engine started
# The vechicle is used for driving

# %%
class Person:
    pass
person=Person()
dir(person)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__']

# %%
print(person)
# Out:
# <__main__.Person object at 0x0000026932F04590>

# %%
##Basic magic methods
class Person:
   def __init__(self,name,age):
     self.name=name
     self.age=age
person=Person("bens",32)
print(person)
# Out:
# <__main__.Person object at 0x0000026932F04590>

# %%
##Basic magic methods
class Person:
   def __init__(self,name,age):
     self.name=name
     self.age=age
   def __str__(self):
      return f"{self.name},{self.age} years old"
   def __repr__(self):
      return f"Person(name={self.name},age={self.age})"
person=Person("bens",32)
print(person)
print(repr(person))
# Out:
# bens,32 years old
# Person(name=bens,age=32)

# %%
#Mathematical Operation 
class Vector:
    def __init__(self,x,y):
        self.x=x
        self.y=y
    def __add__(self,other):
        return Vector(self.x+other.x,self.y+other.y)
    def __sub__(self,other):
        return Vector(self.x-other.x,self.y-other.y)
    def __mul__(self,other):
        return Vector(self.x*other,self.y*other)
    def __eq__(self,other):
        return Vector(self.x==other.x and self.y==other.y)
    def __repr__(self):
        return f"Vector({self.x},{self.y})"
    
v1=Vector(2,3)
v2=Vector(4,5)
print(v1*3)
print(v1+v2)
print(v1-v2)
# Out:
# Vector(6,9)
# Vector(6,8)
# Vector(-2,-2)

# %%
class Error(Exception):
    pass
class dobException(Error):
    pass
year=int(input("Enter the dob"))
age=2024-year

try:
   if age<=30 and age>=20:
      print("The age is valid so you can apply for the exam")
   else:
       raise dobException
except dobException:
    print("Your age is not defined")
# Out:
# The age is valid so you can apply for the exam

# %%
my_list=[1,2,3,4,5,6]
for i in my_list:
    print(i)
print(my_list)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# [1, 2, 3, 4, 5, 6]

# %%
type(my_list)
# Out:
# list

# %%
iterator=iter(my_list)  
print(type(iterator))
# Out:
# <class 'list_iterator'>

# %%
next(iterator)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 next(iterator)
#
# StopIteration:

# %%
try:
    print(next(iterator))
except StopIteration:
    print("There are no elements in the iterator")
# Out:
# There are no elements in the iterator

# %%
mystring="hELLO"
string_iterator=iter(mystring)  
print(next(string_iterator))
print(next(string_iterator))
print(next(string_iterator))
print(next(string_iterator))
print(next(string_iterator))
print(next(string_iterator))
# Out:
# h
# E
# L
# L
# O
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[95], line 8
#       6 print(next(string_iterator))
#       7 print(next(string_iterator))
# ----> 8 print(next(string_iterator))
#
# StopIteration:

# %%
def square(n):
    for i in range(3):
        yield i**2

# %%
a=square(3)
a
# Out:
# <generator object square at 0x00000276AF7ED150>

# %%
next(a)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 next(a)
#
# StopIteration:

# %%
for i in square(3):
    print(i)
# Out:
# 0
# 1
# 4

# %%
def my_generator():
    yield 1
    yield 2
    yield 3

# %%
gen=my_generator()
gen
# Out:
# <generator object my_generator at 0x00000276AFE16F00>

# %%
next(gen)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 next(gen)
#
# StopIteration:

# %%
for val in gen:
    print(val)
# Out:
# 1
# 2
# 3

# %%
def read_large_file(file_path):
    with open(file_path,'r') as file:
        for line in file:
           yield line

# %%
file_path='sample_bistto.txt'
for line in read_large_file(file_path):
    print(line.strip())
# Out:
# # SIEC CALICUT BRANCH - 30 WALK-INS MONTHLY STRATEGY
# *Digital Marketing Action Plan | October 2025*
#
# ## EXECUTIVE SUMMARY
#
# *Goal:* 30 qualified walk-ins per month to SIEC Calicut branch
#
# *Strategy:* Online-only marketing through Meta platforms (Facebook/Instagram) + WhatsApp
#
# *Budget:* ?30,000-50,000/month (?1,000-1,667 per walk-in)
#
# *Timeline:* 4-week tactical campaign with weekly targets
#
# *
#
# ## CAMPAIGN MATH & BENCHMARKS
#
# ### Conversion Funnel
# •?  ?*Required Engaged Leads:* 600-1,500/month
# •?  ?*Lead-to-Walk-in Rate:* 2-5% (industry standard)
# •?  ?*Daily Walk-in Target:* 1 per day average
# •?  ?*Weekly Breakdown:* 5-9 walk-ins per week
#
# ### Budget Allocation
# •?  ?Meta Ads (Facebook/Instagram): ?25,000 (80%)
# •?  ?WhatsApp Marketing Tools: ?3,000 (10%)
# •?  ?Content Creation/Tools: ?2,000 (10%)
#
# *
#
# ## WEEK-BY-WEEK TACTICAL PLAN
#
# ### *WEEK 1: FOUNDATION & EVENT-DRIVEN CAMPAIGN*
# *Target: 5-7 walk-ins*
#
# #### Setup (Day 1-2)
# *Meta Ads Campaign Structure:*
#
# *Ad Set 1: Students (17-21)*
# •?  ?Interests: IELTS, study abroad, universities
# •?  ?Budget: ?300/day
# •?  ?Radius: 10km around SIEC Calicut
#
# *Ad Set 2: Young Graduates (22-25)*
# •?  ?Interests: Career advancement, international jobs
# •?  ?Budget: ?300/day
# •?  ?Radius: 10km around SIEC Calicut
#
# *Ad Set 3: Parents (40-55)*
# •?  ?Interests: Education planning, parenting
# •?  ?Budget: ?300/day
# •?  ?Radius: 15km around SIEC Calicut
#
# #### Campaign Launch (Day 3-7)
# *Offer:* "Free Australia Education Fair - This Saturday at SIEC Calicut"
#
# *Key Elements:*
# •?  ?Limited to 30 students only
# •?  ?Meet university representatives
# •?  ?On-spot profile evaluation
# •?  ?Free entry with registration
#
# *Ad Formats:*
# •?  ?Instagram Stories with countdown stickers
# •?  ?Facebook carousel showing 4 attending universities
# •?  ?WhatsApp click-to-chat CTA: "Reserve Your Spot"
#
# *Follow-up Sequence:*
# •?  ?Immediate: Registration confirmation via WhatsApp
# •?  ?Day before: Reminder with location pin
# •?  ?2 hours before: Final reminder with "See you soon!"
#
# *Expected Results:*
# •?  ?Registrations: 15-20
# •?  ?Actual walk-ins: 5-7 (30-35% show-up rate)
#
# *
#
# ### *WEEK 2: DIRECT WALK-IN INCENTIVE*
# *Target: 7-9 walk-ins*
#
# #### Campaign (Day 8-14)
# *Offer:* "This Week Only: Premium IELTS Prep Kit (?5,000 value)"
#
# *Value Bundle Includes:*
# •?  ?Digital study materials
# •?  ?Practice test access
# •?  ?1-on-1 strategy session
# •?  ?Score improvement tips
#
# *Targeting Strategy:*
# •?  ?Retarget Week 1 engagers who didn't register
# •?  ?Fresh audience: IELTS/PTE preparation interests
# •?  ?Lookalike audience from existing students
#
# *Creative Assets:*
#
# *Instagram Stories:*
# •?  ?15-sec video showing kit contents
# •?  ?Countdown sticker: "5 days left!"
# •?  ?Swipe up: WhatsApp direct message
#
# *Facebook Feed:*
# •?  ?Before/after IELTS scores carousel
# •?  ?Student testimonials from Calicut
# •?  ?"Walk in today" CTA button
#
# *Instagram Reels:*
# •?  ?Manglish testimonial (30 sec)
# •?  ?Caption: "SIEC Calicut inte IELTS help kond 7.5 bands kitty! ??"
# •?  ?Trending audio + local hashtags
#
# *Call-to-Action Protocol:*
# When prospects call/message:
# •?  ?"Limited IELTS kits available - only 8 left this week"
# •?  ?"Can you visit today or tomorrow? We're open until 7 PM"
# •?  ?"Bring your academic documents for instant profile check"
#
# *Expected Results:*
# •?  ?Engaged leads (calls/WhatsApp): 40-50
# •?  ?Walk-ins: 7-9
#
# *
#
# ### *WEEK 3: PARENT TARGETING CAMPAIGN*
# *Target: 6-8 walk-ins*
#
# #### Campaign (Day 15-21)
# *Offer:* "Parents' Guide to Study Abroad - Free Consultation at SIEC Calicut"
#
# *Session Topics:*
# •?  ?Total cost breakdown (tuition + living)
# •?  ?ROI analysis by country
# •?  ?Safety and student welfare
# •?  ?Part-time work and PR pathways
# •?  ?Education loan guidance
#
# *Targeting:*
# •?  ?Age: 40-55
# •?  ?Radius: 15km from Calicut
# •?  ?Interests: Parenting, education planning, investment
# •?  ?Language: Malayalam + English
#
# *Creative Strategy:*
#
# *Video Ad (30 seconds):*
# •?  ?SIEC counselor addressing parent concerns in Malayalam
# •?  ?Key questions: "Paisa waste aavumo? Safe aano? Job kitumo?"
# •?  ?Reassuring tone with facts and figures
# •?  ?CTA: "Book your 1-on-1 consultation"
#
# *Lead Form Fields:*
# •?  ?Parent name
# •?  ?Student name
# •?  ?Preferred destination (dropdown)
# •?  ?Preferred time slot (Morning 10-12 / Evening 5-7)
# •?  ?Phone number (WhatsApp)
#
# *Appointment Confirmation:*
# •?  ?Auto WhatsApp: "Your consultation confirmed at SIEC Calicut on [date] at [time]"
# •?  ?Include: Counselor name, branch address, Google Maps link
# •?  ?What to bring: Student's mark sheets, passport (if available)
#
# *Reminder System:*
# •?  ?Day before: "Looking forward to meeting you tomorrow at [time]"
# •?  ?2 hours before: Personal call from counselor
# •?  ?Reduces no-shows from 40% to 15%
#
# *Expected Results:*
# •?  ?Scheduled appointments: 25-30
# •?  ?Actual walk-ins: 6-8 (75% show-up rate)
#
# *
#
# ### *WEEK 4: RETARGETING & FINAL PUSH*
# *Target: 6-8 walk-ins*
#
# #### Campaign (Day 22-30)
# *Offer:* "Profile Evaluation Week - Know Your Admission Chances"
#
# *What Students Get:*
# •?  ?Free eligibility assessment
# •?  ?Scholarship opportunity analysis
# •?  ?Suitable university recommendations
# •?  ?Application timeline planning
# •?  ?Document checklist
#
# *Retargeting Strategy:*
#
# *Audience Segments:*
# 1.? ?Engaged with Week 1-3 ads but didn't convert
# 2.? ?Visited website but didn't fill form
# 3.? ?Started WhatsApp conversation but didn't visit
# 4.? ?Viewed Instagram content (Stories/Reels)
#
# *Multi-Touch Sequence:*
#
# *Touch 1 (Day 22) - Instagram Story:*
# •?  ?Student testimonial: "Walked into SIEC Calicut with zero hope. They found me $15,000 scholarship!"
# •?  ?15-second video format
# •?  ?"Tap to message" CTA
#
# *Touch 2 (Day 24) - Facebook Feed:*
# •?  ?Image: Friendly SIEC Calicut team photo
# •?  ?Caption: "Only 6 days left this month. Walk-ins welcome - No appointment needed!"
# •?  ?Mention: Open hours Monday-Saturday 9 AM-7 PM
#
# *Touch 3 (Day 26-27) - WhatsApp Direct Message:*
# Template:
# "Hi [Name], I noticed you were interested in studying in [Country]. Our Calicut branch is open until 7 PM this week if you'd like to discuss your options. What time works best for you - weekday evening or weekend?"
#
# *Touch 4 (Day 28-30) - Final Sprint:*
# •?  ?Instagram Reels takeover
# •?  ?Facebook Stories
# •?  ?Message: "Last 3 days! Weekend walk-ins at SIEC Calicut"
# •?  ?Saturday & Sunday: Extended hours 10 AM-6 PM
#
# *Conversion Tactics:*
# •?  ?"We have a 30-minute slot at 5 PM today. Shall I block it for you?"
# •?  ?"Just bring your mark sheets - no other preparation needed"
# •?  ?"Coffee on us! ? Come have a chat about your study plans"
#
# *Expected Results:*
# •?  ?Re-engaged leads: 50-60
# •?  ?Walk-ins: 6-8
#
# *
#
# ## HIGH-IMPACT SPECIFIC TACTICS
#
# ### *1. Geo-Fenced Story Ads*
# *Budget:* ?200-300/day
#
# *Setup:*
# •?  ?Instagram Story ads only
# •?  ?Radius: 3-5km around SIEC Calicut branch
# •?  ?Targeting: "Recent location" (currently nearby or visited recently)
#
# *Creative:*
# •?  ?"You're near SIEC Calicut! ??"
# •?  ?"Walk in now for free profile evaluation"
# •?  ?Address displayed prominently
# •?  ?"Get Directions" button (opens Google Maps)
#
# *Impact:* Targets people who can physically walk in within 10-15 minutes
#
# *Expected:* 2-3 walk-ins per week
#
# *
#
# ### *2. WhatsApp Broadcast Strategy*
#
# *Existing Database Activation:*
# •?  ?Past inquiries
# •?  ?Event attendees
# •?  ?Website visitors who shared numbers
#
# *Weekly Broadcast Schedule:*
#
# *Monday:*
# "This week at SIEC Calicut: Free scholarship search assistance for walk-ins. When can you visit?"
#
# *Wednesday:*
# "Quick reminder: We're open until 7 PM every weekday. Perfect for after-college visits! ?"
#
# *Saturday:*
# "Weekend walk-ins today 10 AM-4 PM. Bring a friend - both get extended consultation!"
#
# *Follow-up Rule:*
# •?  ?Respond to every reply within 30 minutes
# •?  ?Personal tone, not automated
# •?  ?Confirm visit time immediately
#
# *Expected:* 2-4 walk-ins per week from database
#
# *
#
# ### *3. Instagram Location Tag Strategy*
#
# *Daily Activity (15 minutes):*
#
# *Content to Post:*
# •?  ?Student testimonial videos
# •?  ?"Day in the life" at SIEC Calicut branch
# •?  ?Team introductions
# •?  ?University update shares
# •?  ?Scholarship announcements
# •?  ?Visa approval celebrations
#
# *Location Tagging:*
# •?  ?Always use "SIEC Calicut" location tag
# •?  ?Encourage walk-in students to tag and share
# •?  ?Repost student stories to your account
#
# *Discovery Benefit:*
# When students search "study abroad Calicut" on Instagram, your active location appears with recent posts
#
# *Expected:* 1-2 organic walk-ins per week
#
# *
#
# ### *4. Facebook Community Engagement*
#
# *Join Local Groups:*
# •?  ?Calicut Students Forum
# •?  ?Study Abroad Kerala
# •?  ?Kozhikode Education Network
# •?  ?University of Calicut Alumni
# •?  ?College-specific groups (Medical College, Engineering colleges)
#
# *Weekly Activity Plan:*
#
# *Monday:*
# Share valuable content (NOT promotional)
# •?  ?"5 Things to Know About Canada Student Visa 2026"
# •?  ?"Germany Public Universities: Complete Guide"
# •?  ?Document checklist infographic
#
# *Wednesday:*
# Answer student questions genuinely
# •?  ?Respond to queries about admissions, visas, costs
# •?  ?Provide helpful information freely
# •?  ?Build trust and credibility
#
# *Friday:*
# Subtle mention
# •?  ?"Happy to discuss this in detail if anyone wants to drop by SIEC Calicut"
# •?  ?"We're at [address] if you'd like personalized guidance"
#
# *Rules:*
# •?  ?Give value first, promote second
# •?  ?Never spam with ads
# •?  ?Build relationships over transactions
#
# *Expected:* 1-2 walk-ins per week from community trust
#
# *
#
# ### *5. Micro-Influencer Collaboration*
#
# *Target Influencers (5,000-20,000 followers in Calicut):*
# •?  ?Students currently studying abroad from Calicut
# •?  ?IELTS/PTE trainers in Kozhikode
# •?  ?College seniors with engaged followings
# •?  ?Education content creators
#
# *Collaboration Model:*
#
# *Option 1 - Barter:*
# Free services for their juniors/followers in exchange for authentic content
#
# *Option 2 - Minimal Payment:*
# ?2,000-3,000 per influencer for 2-3 posts/stories
#
# *Content Brief:*
# •?  ?Visit SIEC Calicut branch
# •?  ?Get profile evaluation
# •?  ?Meet counselors
# •?  ?Share genuine experience in Manglish
# •?  ?Example: "Guys, SIEC Calicut inte team super helpful aayirunnu. Planning study abroad enkilum onnu check cheyyuka ??"
#
# *Platform:* Instagram Stories + 1 Reel
#
# *Expected:* 3-5 walk-ins per influencer campaign
#
# *
#
# ## META ADS GEO-TARGETING SETUP GUIDE
#
# ### *Step-by-Step Configuration*
#
# *1. Access Ads Manager*
# •?  ?Go to business.facebook.com
# •?  ?Click "Create" new campaign
# •?  ?Choose objective: "Lead Generation" or "Traffic"
#
# *2. Ad Set Level - Location Setup*
# •?  ?Navigate to "Audience Controls"
# •?  ?Click "Locations"
# •?  ?Remove default "India" location
#
# *3. Define Calicut Geofence*
# •?  ?Search: "Calicut" or "Kozhikode"
# •?  ?Set radius: 10-15km for general campaigns
# •?  ?Or use "Drop Pin" feature for precision targeting
#
# *4. Drop Pin Method (Advanced)*
# •?  ?Click map icon in location settings
# •?  ?Drop pin exactly on SIEC Calicut branch
# •?  ?Adjust radius slider (5km for hyper-local, 15km for broader)
#
# *5. Location Refinement*
# •?  ?Default: "Living in or recently in this location"
# •?  ?Use exclusions if getting leads from nearby cities
# •?  ?Example: Exclude Malappuram, Kannur if Calicut-only desired
#
# *6. Additional Targeting Layers*
# •?  ?*Age:* 17-24 (students) OR 40-55 (parents)
# •?  ?*Language:* Malayalam + English
# •?  ?*Interests:* Study abroad, IELTS, specific countries
# •?  ?*Behaviors:* College grads, engaged shoppers
#
# *7. Create Location-Specific Ad Copy*
# Example: "Calicut students - Start your Australia journey at SIEC Kozhikode branch. Walk-ins welcome!"
#
# *8. Add Local References*
# •?  ?"Near Medical College Road"
# •?  ?"Opposite [landmark]"
# •?  ?Include exact address in ad
#
# *
#
# ## WEEKLY PERFORMANCE TRACKING
#
# ### *Monitor Every Monday:*
#
# | *Metric* | *Week 1* | *Week 2* | *Week 3* | *Week 4* | *Monthly Total* |
# |------------|------------|------------|------------|------------|-------------------|
# | Total Leads | 60-80 | 70-90 | 80-100 | 90-120 | 300-390 |
# | WhatsApp Inquiries | 20-25 | 25-30 | 30-35 | 35-40 | 110-130 |
# | Phone Calls | 10-12 | 12-15 | 15-18 | 15-20 | 52-65 |
# | Appointments Scheduled | 5-7 | 8-10 | 12-15 | 10-12 | 35-44 |
# | *Actual Walk-ins* | *5-7* | *7-9* | *6-8* | *6-8* | *30* |
# | Cost per Walk-in | ?1,071-1,500 | ?833-1,071 | ?938-1,250 | ?938-1,250 | ?1,000-1,667 |
#
# ### *What to Track:*
# •?  ?Which ad sets perform best
# •?  ?Peak inquiry times (adjust ad scheduling)
# •?  ?Geo-location breakdown (which areas in Calicut respond best)
# •?  ?Content type performance (video vs image vs carousel)
# •?  ?Walk-in source attribution ("How did you hear about us?")
#
# *
#
# ## CONVERSION OPTIMIZATION PROTOCOLS
#
# ### *Immediate Response System*
#
# *5-Minute Response Rule:*
# •?  ?Respond to ALL leads within 5 minutes
# •?  ?Increases conversion by 400%
# •?  ?Use WhatsApp Business quick replies
#
# *Response Templates:*
#
# *For WhatsApp Inquiries:*
# "Hi [Name]! Thanks for your interest in studying in [Country]. I'm [Counselor Name] from SIEC Calicut. When would you like to visit our branch - today evening or tomorrow?"
#
# *For Phone Calls:*
# "Great to hear from you! We have slots available this week. Can you visit our Calicut branch today at [time] or tomorrow at [time]? I'll personally handle your consultation."
#
# *For Form Submissions:*
# "Thanks for registering! Your free [offer] is ready at SIEC Calicut. We're at [address] - open until 7 PM today. When can we expect you?"
#
# *
#
# ### *Friction Reduction Tactics*
#
# *Make Walk-ins Effortless:*
# •?  ?Never require online registration first
# •?  ?Accept walk-ins without appointments
# •?  ?Display clear walk-in hours in every ad
# •?  ?Share Google Maps location link in every conversation
#
# *Remove Hesitation:*
# •?  ?"No commitment required - just come for a chat ?"
# •?  ?"Bring just your mark sheets - nothing else needed"
# •?  ?"Consultation is 100% free - always has been, always will be"
# •?  ?"We're students' advocates, not salespeople"
#
# *
#
# ### *Urgency Creation (Without Discounts)*
#
# *Time-Limited Availability:*
# •?  ?"We have limited slots for January 2026 intake counseling this week"
# •?  ?"Our Canada immigration expert is at Calicut branch only until Friday"
# •?  ?"Only 5 IELTS prep kits remaining this month"
#
# *Event-Based Urgency:*
# •?  ?"University application deadlines approaching - walk in for timeline planning"
# •?  ?"Scholarship application season - early profile evaluation recommended"
#
# *Scarcity (Honest):*
# •?  ?"We can take only 30 new students for this intake to maintain quality"
# •?  ?"Limited seats in our group visa application session"
#
# *
#
# ## CONTINGENCY PLAN (IF BELOW TARGET)
#
# ### *If Fewer Than 12 Walk-ins by End of Week 2:*
#
# *Immediate Actions:*
#
# *1. Budget Reallocation (Same Day)*
# •?  ?Increase budget by 30-50% on best-performing ad set
# •?  ?Pause underperforming ad sets
# •?  ?Redirect spend to what's working
#
# *2. Emergency Walk-in Drive (Launch Friday)*
#
# *Weekend Blitz Campaign:*
# "This Weekend Only: Extended Hours + Special Walk-in Benefits"
#
# *Offer:*
# •?  ?Saturday & Sunday: 10 AM-6 PM
# •?  ?Walk in and receive Premium Study Abroad Guide (?3,000 value)
# •?  ?Meet senior counselor for 45-minute consultation
# •?  ?Free refreshments
#
# *Promotion:*
# •?  ??2,000 flash ad budget Friday-Saturday
# •?  ?WhatsApp broadcast to all leads
# •?  ?Instagram Stories takeover
#
# *3. Personal Calling Campaign*
# •?  ?Call top 50 engaged leads personally
# •?  ?Script: "I noticed you're seriously interested in [Country]. I'd love to help. Can you visit our Calicut branch this Saturday? I'll personally handle your case."
# •?  ?Conversational, not salesy
#
# *4. Extended Hours*
# •?  ?Open until 9 PM Thursday and Friday
# •?  ?"Special extended hours for working parents and evening students"
# •?  ?Promote heavily: "Can't make it during day? We're open late this week!"
#
# *5. Referral Activation*
# •?  ?Contact recent walk-ins: "Know anyone planning to study abroad? Bring them this week and both get premium services"
# •?  ?Offer genuine value, not cash incentives
#
# *
#
# ## SUCCESS MULTIPLIERS
#
# ### *Photo Wall Strategy*
#
# *Implementation:*
# •?  ?Take photo of every walk-in visitor (with permission)
# •?  ?Branded backdrop at branch entrance
# •?  ?"Thank you for visiting SIEC Calicut!" frame
#
# *Social Media Usage:*
# •?  ?Post daily on Instagram Stories
# •?  ?Caption: "Thanks for visiting SIEC Calicut today, [Name]! Best wishes for your [Country] journey ????"
# •?  ?Tag the student (if they have Instagram)
#
# *Impact:*
# •?  ?Creates social proof
# •?  ?Shows active branch
# •?  ?Generates FOMO among prospects
# •?  ?Previous walk-ins share to their network
#
# *
#
# ### *Same-Day Testimonial Collection*
#
# *Process:*
# Before walk-in leaves (if consultation went well):
# 1.? ?"Would you mind sharing your experience in a quick 15-second video?"
# 2.? ?Record on their phone or yours
# 3.? ?Ask: "What did you like about visiting SIEC Calicut today?"
#
# *Usage:*
# •?  ?Post within 2 hours on Instagram Reels/Stories
# •?  ?Authentic, unpolished testimonials work best
# •?  ?Use geotag: "SIEC Calicut"
# •?  ?Caption: "Fresh feedback from today's walk-in! ??"
#
# *Expected Impact:*
# •?  ?Genuine testimonials convert 3x better than staged ones
# •?  ?Same-day posting shows active, trustworthy business
#
# *
#
# ### *Walk-in Referral Bonus*
#
# *Offer Given to Every Walk-in:*
# "Loved our consultation? Bring a friend this week and both of you get extended scholarship search service + application timeline planning (?4,000 combined value)"
#
# *How It Works:*
# •?  ?Converts 1 walk-in into 2
# •?  ?Word-of-mouth from satisfied visitors
# •?  ?Time-limited (this week only) creates urgency
#
# *Tracking:*
# •?  ?Ask new walk-ins: "Did someone refer you?"
# •?  ?Reward both parties when they visit together or separately
#
# *Expected:* 20-30% of walk-ins bring a referral
#
# *
#
# ## KEY SUCCESS FACTORS
#
# ### *Critical Elements for 30 Walk-ins:*
#
# ? *Response Speed:* Reply to every lead within 5 minutes
# ? *Geo-Precision:* Target only 10-15km radius around Calicut
# ? *Value-First Messaging:* Never mention discounts, only valuable add-ons
# ? *Multi-Touch Retargeting:* Engage leads 3-4 times before they convert
# ? *Friction Removal:* Make walking in as easy as possible
# ? *Personal Touch:* Human responses, not automated
# ? *Consistent Tracking:* Monitor daily, adjust weekly
# ? *Local Language:* Manglish content performs 40% better in Kerala
# ? *Social Proof:* Daily posts showing active branch with real students
# ? *Urgency (Honest):* Limited availability, not fake scarcity
#
# *
#
# ## CONTENT CALENDAR TEMPLATE
#
# ### *Daily Posting Schedule:*
#
# *Monday:*
# •?  ?1 Instagram Feed post: Educational content (university spotlight)
# •?  ?2 Instagram Stories: Weekend walk-in recap + This week's offer
# •?  ?1 Facebook post: Blog share or news update
#
# *Tuesday:*
# •?  ?3 Instagram Stories: Student testimonial, office culture, study tip
# •?  ?1 WhatsApp broadcast: Weekly offer reminder
#
# *Wednesday:*
# •?  ?1 Instagram Reel: 30-sec student success story (Manglish)
# •?  ?2 Facebook Stories: Same content repurposed
# •?  ?Community engagement: Answer 5 questions in groups
#
# *Thursday:*
# •?  ?1 Instagram Feed: Infographic (visa process/scholarships)
# •?  ?3 Stories: Behind-the-scenes, team introduction, walk-in photo
# •?  ?1 WhatsApp broadcast: Mid-week reminder
#
# *Friday:*
# •?  ?1 Instagram Reel: Weekly roundup or trending topic
# •?  ?2 Stories: Weekend walk-in hours, special offer
# •?  ?Facebook post: Share Reel to Feed
#
# *Saturday:*
# •?  ?Live Instagram Story coverage: Walk-ins, consultations (with permission)
# •?  ?Real-time engagement: Q&A sessions
#
# *Sunday:*
# •?  ?1 Instagram Feed: Inspirational/motivational content
# •?  ?Planning for next week's campaigns
#
# *
#
# ## MESSAGING FRAMEWORKS
#
# ### *For Students (17-24 years):*
#
# *Hook:* Relatable pain point
# "Confused about which country suits your budget and career goals?"
#
# *Value Proposition:* Clear benefit
# "Walk into SIEC Calicut this week and get personalized country comparison based on YOUR profile - not generic advice"
#
# *Social Proof:* Peer validation
# "500+ Calicut students already studying abroad through SIEC"
#
# *CTA:* Easy next step
# "DM us or walk in today - we're open until 7 PM"
#
# *
#
# ### *For Parents (40-55 years):*
#
# *Hook:* Address concerns directly
# "Worried about your child's safety and career prospects abroad?"
#
# *Value Proposition:* ROI and security
# "Free parent consultation at SIEC Calicut - understand true costs, loan options, PR pathways, and safety measures"
#
# *Authority:* Trust building
# "30+ years in overseas education | Gold-rated by top universities"
#
# *CTA:* Respectful invitation
# "Book your appointment or walk in at your convenience. We understand this is a major decision."
#
# *
#
# ## TOOLS & RESOURCES NEEDED
#
# ### *Essential Tools:*
#
# *Free:*
# •?  ?WhatsApp Business (lead management)
# •?  ?Meta Business Suite (ad management)
# •?  ?Google Analytics (website tracking)
# •?  ?Canva Free (content creation)
# •?  ?CapCut (video editing)
#
# *Paid (Optional but Recommended):*
# •?  ?Canva Pro: ?500/month (branded templates)
# •?  ?Later or Buffer: ?600/month (social media scheduling)
# •?  ?CallRail or similar: ?1,500/month (call tracking)
#
# ### *Content Creation Assets:*
#
# *Must-Have:*
# •?  ?20-30 stock photos of SIEC Calicut branch
# •?  ?5-10 student testimonial videos (15-30 seconds each)
# •?  ?University logo pack (for carousels)
# •?  ?Branded templates (Instagram Stories, Feed posts, Reels)
#
# *Weekly Creation:*
# •?  ?3-4 Reels per week
# •?  ?7-10 Stories per day
# •?  ?2-3 Feed posts per week
# •?  ?1-2 carousel posts per week
#
# *
#
# ## FINAL CHECKLIST
#
# ### *Before Campaign Launch:*
#
# *Technical Setup:*
# •?  ?[ ] Meta Business Manager account active
# •?  ?[ ] Facebook Page verified
# •?  ?[ ] Instagram Business account connected
# •?  ?[ ] WhatsApp Business number set up
# •?  ?[ ] Meta Pixel installed on website
# •?  ?[ ] Payment method added to Ads Manager
# •?  ?[ ] Geo-targeting configured (10-15km Calicut radius)
#
# *Content Preparation:*
# •?  ?[ ] Week 1 ad creatives ready (6-8 variations)
# •?  ?[ ] WhatsApp quick reply templates saved
# •?  ?[ ] Response protocol shared with team
# •?  ?[ ] Branch photos for social proof taken
# •?  ?[ ] Student testimonials collected (video + text)
#
# *Team Readiness:*
# •?  ?[ ] Counselors briefed on campaign offers
# •?  ?[ ] Response time protocol established (5 minutes)
# •?  ?[ ] Walk-in greeting process standardized
# •?  ?[ ] Tracking system in place ("How did you hear about us?")
# •?  ?[ ] Follow-up procedures documented
#
# *Measurement:*
# •?  ?[ ] Weekly tracking sheet created
# •?  ?[ ] Attribution system ready
# •?  ?[ ] Cost-per-lead targets set
# •?  ?[ ] Success metrics defined
# •?  ?[ ] Weekly review meeting scheduled (every Monday 10 AM)
#
# CONCLUSION
#
# This strategy is designed to systematically generate 30 qualified walk-ins to SIEC Calicut branch through focused, geo-targeted online campaigns. Success depends on:
#
# 1.? ?*Precision targeting* (right audience, right location, right time)
# 2.? ?*Immediate response* (5-minute rule for all inquiries)
# 3.? ?*Value-first approach* (no discounts, only genuine add-ons)
# 4.? ?*Consistent execution* (daily content, weekly optimization)
# 5.? ?*Personal touch* (human connections, not automation)
#
# *Start Date:* Week 1, Day 1
# *Review Date:* Every Monday
# *Optimization:* Continuous based on data
# *Expected Outcome:* 30 walk-ins in 30 days
#
# *
#
# *Document Prepared For:* SIEC Calicut Branch Marketing Team
# *Date:* October 30, 2025
# *Valid For:* Monthly recurring campaigns with seasonal adjustments

# %%
def welcome():
    return "welcome to advance python course"
welcome()
# Out:
# 'welcome to advance python course'

# %%
wel=welcome
print(wel())
del welcome
print(wel())
# Out:
# welcome to advance python course
# welcome to advance python course

# %%
##closures
def main_welcome(msg):
    
    def sub_welcome_method():
        print("welcome to the advance python course")
        print(msg)
        print("please lean ir properly")
    return sub_welcome_method()

# %%
main_welcome("welcome evryone")
# Out:
# welcome to the advance python course
# welcome evryone
# please lean ir properly

# %%
def main_welcome(func):
    
    def sub_welcome_method():
        print("welcome to the advance python course")
        func("Welcome everyone to this tutorial")
        print("please lean ir properly")
    return sub_welcome_method()

# %%
main_welcome(print)
# Out:
# welcome to the advance python course
# Welcome everyone to this tutorial
# please lean ir properly

# %%
def main_welcome(func,lst):
    
    def sub_welcome_method():
        print("welcome to the advance python course")
        print(func(lst))
        print("please lean ir properly")
    return sub_welcome_method()

# %%
main_welcome(len,[1,2,3,4,5,6,7])
# Out:
# welcome to the advance python course
# 7
# please lean ir properly

# %%
len([1,2,3,4,5,6,7])
# Out:
# 7

# %%
def main_welcome(func):
    
    def sub_welcome_method():
        print("welcome to the advance python course")
        func()
        print("please lean ir properly")
    return sub_welcome_method()

# %%
@main_welcome
def course_intro():
    print("its important")
# Out:
# welcome to the advance python course
# its important
# please lean ir properly

# %%
def my_decorator(func):
    
    def wrapper():
        print("welcome to the advance python course")
        func()
        print("please lean ir properly")
    return wrapper

# %%
@my_decorator
def say_hello():
    print("Hello")

# %%
say_hello()
# Out:
# welcome to the advance python course
# Hello
# please lean ir properly

# %%
def repeat(n):
    def decorator(func):
        def wrapper(*args,**kwargs):
            for _ in range(n):
                func(*args,**kwargs)
        return wrapper
    return decorator

# %%
@repeat(3)
def say_hello():
    print("Hello")

# %%
say_hello()
# Out:
# Hello
# Hello
# Hello

# %%
@repeat(6)
def bens():
    print("asdasdasda")

# %%
bens()
# Out:
# asdasdasda
# asdasdasda
# asdasdasda
# asdasdasda
# asdasdasda
# asdasdasda
